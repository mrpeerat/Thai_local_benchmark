# %%
from glob import glob
import pandas as pd

# %%
tasks = ["qa","summarization","translation"]

# %%
model = "llama-3-typhoon-v1.5x-70b-instruct"

# %%
zone = "east"

# %%
for task in tasks:
    for file in glob(f"outputs_local/{task}*{zone}_*_{model}.csv"):
        df = pd.read_csv(file)

# %%
#sum
pd.read_csv("outputs_local/summarization_north_0_0_llama-3-typhoon-v1.5x-8b-instruct.csv")
# Out:
#                                                 Input  \
# 0   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 1   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 2   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 3   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 4   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 5   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 6   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 7   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 8   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 9   หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 10  หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 11  หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 12  หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 13  หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 14  หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# 15  หื้อสรุปข้อความตางล่างหือเป็นภาษาเหนือ\nข้อควา...
# ...
